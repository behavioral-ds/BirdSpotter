# %%
from BirdSpotter import BirdSpotter
bs = BirdSpotter()
bs.extractTweets('AustralianPolitics.json', tweetLimit=1000, embeddings='word2vec.pickle')
# bs.featureDataframe
# Out:
# Loading Word2Vec Embeddings...
# Finished loading Word2Vec Embeddings
# /home/admin-u5568718/honours/crawl/Experiment/BotSpotting2/BotSpot.py:180: RuntimeWarning: invalid value encountered in true_divide
#   vec = vec/tol
#                      description_n_caps  description_n_capsp  \
# user_id
# 690003                             24.0             0.200000
# 3698221                             1.0             0.086957
# 3698221                             1.0             0.086957
# 3698221                             1.0             0.086957
# 3698221                             1.0             0.086957
# 3698221                             1.0             0.086957
# 3698221                             1.0             0.086957
# 6174712                            20.0             0.132911
# 7228882                             9.0             0.123457
# 9609632                             6.0             0.112903
# 12058462                            1.0             0.111111
# ...

# %%
# One can train the bot spotter or load a pretrained model
bs.trainClassifierModel("train.pickle")
# bs.loadClassifierModel('saved_model')

# %%
# A pandas dataframe can be found under bs.botnessDataframe
bs.getBotness()
# Out:
#                       botness
# user_id
# 690003               0.693322
# 3698221              0.475251
# 3698221              0.475251
# 3698221              0.475251
# 3698221              0.475251
# 3698221              0.475251
# 3698221              0.475251
# 6174712              0.888447
# 7228882              0.630624
# 9609632              0.940598
# 12058462             0.447324
# 14795444             0.224966
# 15225512             0.687877
# 15225512             0.687877
# 15460053             0.730046
# 15514389             0.765066
# 15843498             0.460572
# 15843498             0.460572
# 15843498             0.460572
# 16091981             0.665692
# 16094885             0.808888
# 16094885             0.808888
# 16166464             0.799417
# 16273000             0.612090
# 16375083             0.504273
# 16883717             0.338314
# 17201795             0.843242
# 17560966             0.654297
# 17560966             0.654297
# ...
